# %%
import tweepy          
import pandas as pd    
import numpy as np      
from tweepy import *

# %%
# Twitter App access keys 

CONSUMER_KEY    = '1CVRNEuCvgbew3KtEua3M3fEq'
CONSUMER_SECRET = 'IbPIFytSbwbkvJgQiHZReQKoZuwNAnmUfayJbmftC57hZ45KDN'


ACCESS_TOKEN  = '2567252275-KQpbaGkAdUqtkO9Z3qtHfs2QFliciZt09zqclaJ'
ACCESS_SECRET = 'dDp1XswlPbWK9sAgSwkH3ZSbsRfrNStRyargDFHaI2n2m'

# %%
def twitter_setup():

    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api
twitter_setup()

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
results = extractor.user_timeline(screen_name="IPL", count=30)
print("Number of tweets extracted: {}.\n".format(len(results)))

# We print the most recent 5 tweets:

for tweet in results:
    print(tweet.text)
# Out:
# Number of tweets extracted: 30.
#
# Inching closer to the LIVE action! 😎
#
# The stage is set. 👌 👌
#
# 3⃣, 2⃣, 1⃣ &amp; HERE WE GO! 👍 👍 #VIVOIPL #SRHvCSK… https://t.co/0CBlXxOmHN
# Team News
#
# @SunRisers remain unchanged.
#
# 1⃣ change for @ChennaiIPL as @DJBravo47 returns to the team. #VIVOIPL… https://t.co/tgAuOXPiRm
# Match 44. Chennai Super Kings XI: F du Plessis, R Gaikwad, M Ali, A Rayudu, S Raina, MS Dhoni, R Jadeja, DJ Bravo,… https://t.co/Q7f7sqIwMA
# 🚨 Toss Update from Sharjah 🚨
#
# @ChennaiIPL have elected to bowl against @SunRisers. #VIVOIPL #SRHvCSK
#
# Follow the ma… https://t.co/NGgPSg6CTB
# Match 44. Sunrisers Hyderabad XI: J Roy, W Saha, K Williamson, P Garg, A Sharma, J Holder, A Samad, R Khan, B Kumar… https://t.co/TieYwzVJ31
# Match 44. Chennai Super Kings win the toss and elect to field https://t.co/vLFIiI3XSE #SRHvCSK #VIVOIPL #IPL2021
# Welcome to Match 44 of the 2021 #VIVOIPL between SRH and CSK https://t.co/vLFIiI3XSE #SRHvCSK #VIVOIPL #IPL2021
# Eying yet another WIN? 🤔
#
# #VIVOIPL #SRHvCSK https://t.co/QkGHLbVfoi
# Captain Kane or Fantastic Faf❓
#
# Who will score more runs tonight 🤔
#
# #VIVOIPL #SRHvCSK https://t.co/PovSBfRDFd
# Hello &amp; welcome from Sharjah for Match 44 of the #VIVOIPL 👋
#
# Kane Williamson's @SunRisers square off against the… https://t.co/fRIhLkGD2m
# .@rashidkhan_19 starred with the ball when @SunRisers took on #CSK the last time in the #VIVOIPL. 👍 👍
#
# Let's revisi… https://t.co/FAAx4x8zAT
# RT @ShuklaRajiv: Well done @BCCI ! Keep it up @IPL
# RT @JayShah: I am delighted to share that #IPL2021 continues to register significant growth in viewership
#
# 📈
# 380 million TV viewers (till m…
# A superb 7⃣5⃣-run knock from @Ruutu1331 in the run-chase guided #CSK home when they played #SRH the last time. 👏 👏… https://t.co/DPTXcF8Ah7
# Shahbaz Ahmed's twin strikes, @KonaBharat  impressive batting display in the run-chase courtesy some exquisite shot… https://t.co/wmLUpbVKzz
# All ears as @imVkohli speaks 👌 👌
#
# #VIVOIPL #RRvRCB https://t.co/9sj9Z5D1wL
# 5⃣0⃣* Runs
# 3⃣0⃣ Balls
# 6⃣ Fours
# 1⃣ Six
#
# @Gmaxi_32 notched up his second successive half-century of the #VIVOIPL &amp; gu… https://t.co/1nI8XXA3Dr
# .@KonaBharat and Shahbaz Ahmed all smiles for the #IPLSelfie after #RCB's win.
#
# #VIVOIPL https://t.co/nsUpXETsZy
# READ: An all-round bowling performance &amp; Glenn Maxwell-KS Bharat's solid show with the bat power @RCBTweets to a 7⃣… https://t.co/vMmasLpNlN
# A look at the Points Table after Match 43 of #VIVOIPL. https://t.co/07aYw3Lcvq
# .@Upstox Most Valuable Asset of the Match between @rajasthanroyals and @RCBTweets is Evin Lewis.
#
# #StartKarkeDekho… https://t.co/7KjfmLIlMC
# Award for CRED Power Player of the Match between @rajasthanroyals and @RCBTweets goes to Evin Lewis.
#
# @CRED_club… https://t.co/vQwx5eQMs3
# Unacademy Lets Crack It Sixes of the Match award between @rajasthanroyals and @RCBTweets goes to Evin Lewis.… https://t.co/u1iXfqFNkI
# Dream11 GameChanger of the Match between @rajasthanroyals and @RCBTweets is Evin Lewis.
#
# @Dream11… https://t.co/tHX345VRM5
# Safari Super Striker of the Match between @rajasthanroyals and @RCBTweets is Glenn Maxwell.
#
# @TataMotors… https://t.co/s0xWKH1ADO
# VIVO Perfect Catch of the Match award between @rajasthanroyals and @RCBTweets goes to Devdutt Padikkal.… https://t.co/l9BdVGoY9Q
# Yuzvendra Chahal is adjudged Man of the Match for his brilliant spell as #RCB beat #RR by 7 wickets to add two more… https://t.co/0UZ1B15QC1
# RT @sharjahstadium: No PCR test is required to attend the IPL matches in Sharjah starting today.
# The authorities have also lifted the minim…
# A match winning FIFTY for @Gmaxi_32 as @RCBTweets win by 7 wickets against #RR.
#
# Scorecard -… https://t.co/cWpgt3Cl1n
# Match 43. It's all over! Royal Challengers Bangalore won by 7 wickets https://t.co/nORWT9iLHL #RRvRCB #VIVOIPL #IPL2021

# %%
# create a pandas dataframe :
data = pd.DataFrame(data=[tweet.text for tweet in results], columns=['Tweets'])
display(data.head(15))
# Out:
#                                                Tweets
# 0   Inching closer to the LIVE action! 😎\n\nThe st...
# 1   Team News\n\n@SunRisers remain unchanged. \n\n...
# 2   Match 44. Chennai Super Kings XI: F du Plessis...
# 3   🚨 Toss Update from Sharjah 🚨\n\n@ChennaiIPL ha...
# 4   Match 44. Sunrisers Hyderabad XI: J Roy, W Sah...
# 5   Match 44. Chennai Super Kings win the toss and...
# 6   Welcome to Match 44 of the 2021 #VIVOIPL betwe...
# 7   Eying yet another WIN? 🤔\n\n#VIVOIPL #SRHvCSK ...
# 8   Captain Kane or Fantastic Faf❓\n\nWho will sco...
# 9   Hello &amp; welcome from Sharjah for Match 44 ...
# 10  .@rashidkhan_19 starred with the ball when @Su...
# 11  RT @ShuklaRajiv: Well done @BCCI ! Keep it up ...
# 12  RT @JayShah: I am delighted to share that #IPL...
# 13  A superb 7⃣5⃣-run knock from @Ruutu1331 in the...
# 14  Shahbaz Ahmed's twin strikes, @KonaBharat  imp...

# %%
print(dir(results[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
print(results[0].id)
print(results[0].created_at)
print(results[0].source)
print(results[0].favorite_count)
print(results[0].retweet_count)
print(results[0].retweeted)
# Out:
# 1443575935131795462
# 2021-09-30 13:58:17
# Twitter Web App
# 580
# 77
# False

# %%
data['ID']   = np.array([tweet.id for tweet in results])
data['Date'] = np.array([tweet.created_at for tweet in results])
data['len']  = np.array([len(tweet.text) for tweet in results])
data['Source'] = np.array([tweet.source for tweet in results])
data['Likes']  = np.array([tweet.favorite_count for tweet in results])
data['Retweets']    = np.array([tweet.retweet_count for tweet in results])

# %%
# Display of first 20 elements from dataframe:
display(data.head(20))
# Out:
#                                                Tweets                   ID  \
# 0   Inching closer to the LIVE action! 😎\n\nThe st...  1443575935131795462
# 1   Team News\n\n@SunRisers remain unchanged. \n\n...  1443570726011764750
# 2   Match 44. Chennai Super Kings XI: F du Plessis...  1443570303813275650
# 3   🚨 Toss Update from Sharjah 🚨\n\n@ChennaiIPL ha...  1443570168869785601
# 4   Match 44. Sunrisers Hyderabad XI: J Roy, W Sah...  1443570122422095873
# 5   Match 44. Chennai Super Kings win the toss and...  1443569276422602753
# 6   Welcome to Match 44 of the 2021 #VIVOIPL betwe...  1443569276401618947
# 7   Eying yet another WIN? 🤔\n\n#VIVOIPL #SRHvCSK ...  1443568490225405953
# 8   Captain Kane or Fantastic Faf❓\n\nWho will sco...  1443565976092504070
# 9   Hello &amp; welcome from Sharjah for Match 44 ...  1443554347971854338
# 10  .@rashidkhan_19 starred with the ball when @Su...  1443528769696763906
# 11  RT @ShuklaRajiv: Well done @BCCI ! Keep it up ...  1443524134038769665
# 12  RT @JayShah: I am delighted to share that #IPL...  1443524086286614540
# 13  A superb 7⃣5⃣-run knock from @Ruutu1331 in the...  1443508282824347649
# 14  Shahbaz Ahmed's twin strikes, @KonaBharat  imp...  1443425372687667201
# 15  All ears as @imVkohli speaks 👌 👌\n\n#VIVOIPL #...  1443305521436499972
# 16  5⃣0⃣* Runs\n3⃣0⃣ Balls\n6⃣ Fours\n1⃣ Six\n\n@G...  1443292074393030656
# 17  .@KonaBharat and Shahbaz Ahmed all smiles for ...  1443287300708962309
# 18  READ: An all-round bowling performance &amp; G...  1443284818595250180
# 19  A look at the Points Table after Match 43 of #...  1443281290040692743
#
#                   Date  len                    Source  Likes  Retweets
# 0  2021-09-30 13:58:17  136           Twitter Web App    580        77
# 1  2021-09-30 13:37:35  136           Twitter Web App   1068       110
# 2  2021-09-30 13:35:55  139               IPLT20 Live    600        74
# 3  2021-09-30 13:35:23  140           Twitter Web App    963       110
# 4  2021-09-30 13:35:12  140               IPLT20 Live    380        34
# 5  2021-09-30 13:31:50  112               IPLT20 Live    428        50
# 6  2021-09-30 13:31:50  111               IPLT20 Live    285        27
# 7  2021-09-30 13:28:42   67           Twitter Web App   1399       163
# 8  2021-09-30 13:18:43  109           Twitter Web App   1378        84
# 9  2021-09-30 12:32:31  141           Twitter Web App   2333       200
# 10 2021-09-30 10:50:52  140  Twitter for Advertisers.    988        52
# 11 2021-09-30 10:32:27   50           Twitter Web App      0        82
# 12 2021-09-30 10:32:16  140           Twitter Web App      0       805
# 13 2021-09-30 09:29:28  139  Twitter for Advertisers.   2305       196
# 14 2021-09-30 04:00:01  140      Twitter Media Studio   1480       113
# 15 2021-09-29 20:03:46   74           Twitter Web App   6886       756
# 16 2021-09-29 19:10:20  144           Twitter Web App    999        85
# 17 2021-09-29 18:51:22  112           Twitter Web App   1901        85
# 18 2021-09-29 18:41:30  144           Twitter Web App    656        40
# 19 2021-09-29 18:27:29   78           Twitter Web App   8163       533
